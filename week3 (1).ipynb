# %%
import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
# Out:
# /kaggle/input/titanic.txt

# %%
import matplotlib.pyplot as plt

plt.figure(1, figsize=(10,5))
data = [2,4,6,5,7,6,8,5,4,6,8,10]
plt.subplot(1,3,1)
plt.xlabel('x')
plt.xlabel('y')
plt.title('pepepepe')
plt.plot(data)

plt.figure(1, figsize=(10,5))
data = [2,4,6,5,7,6,8,5,4,6,8,10]
plt.subplot(1,3,2)
plt.xlabel('x')
plt.xlabel('y')
plt.title('pepepepeqq')
plt.plot(data)

plt.figure(1, figsize=(10,5))
data = [2,4,6,5,7,6,8,5,4,6,8,12]
plt.subplot(1,3,3)
plt.xlabel('x')
plt.xlabel('y')
plt.title('pepepepebb')
   
plt.plot(data)

plt.show()

# %%
fig = plt.figure(1, figsize=(15,6))

# bar chart example
accounts = ['fabiyamada', 'jedigeiss', 'scipio', 'stoodkev']
steem = [1100, 500, 1200, 2300]

plt.subplot(1,2,1)
plt.title('Bar chart')
plt.ylabel('Steem')
plt.bar(accounts, steem)

# pie chart example
labels = 'fabiyamada', 'jedigeiss', 'scipio', 'stoodkev'
perc = [steem[0]/sum(steem), # calculate percentages from the amount of steem
        steem[1]/sum(steem), 
        steem[2]/sum(steem), 
        steem[3]/sum(steem)]

explode = (0, 0, 0.1, 0)     # "explode" the 3rd slice ('Scipio')

plt.subplot(1,2,2)
plt.title('Pie chart')
plt.axis('equal')            # Make sure the pie is drawn as a circle, X and Y axes equally sized
plt.pie(perc, labels=labels, autopct='%1.2f%%', 
        startangle=90, explode=explode)

plt.show()

# %%
import numpy as np
x = np.linspace(0,10,100)
plt.plot(x, np.sin(x))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-28c5f32b99ed> in <module>
# ----> 1 x = np.linspace(0,10,100)
#       2 plt.plot(x, np.sin(x))
#
# NameError: name 'np' is not defined

# %%
titanics = np.genfromtxt('/kaggle/input/titanic.txt',delimiter='\t',missing_values = None,dtype=str)

# %%
titanics[0,:]

# %%
titanics[:,3]

# %%
titanics = np.delete(titanics,[1,6,7,8,9,10],1)

# %%
titanics[0,:]

# %%
rows, cols = np.where(titanics == None)
rows

# %%
rows, cols = np.where(titanics == '')
np.unique(rows)

# %%
rows, cols = np.where(titanics == '')
print(str(len(np.unique(rows)))+" "+str(len(np.unique(cols))))

# %%
np.unique(cols)

# %%
titanics = np.delete(titanics,2,1)
titanics[0,:]

# %%
passenger_class = np.unique(titanics[1:,0])
passenger_class

# %%
passenger_class_value = [sum(titanics[:,0]==passenger_class[0]),
                         sum(titanics[:,0]==passenger_class[1]),
                         sum(titanics[:,0]==passenger_class[2]) ]
passenger_class_value

# %%
plt.bar(passenger_class, passenger_class_value)

# %%
passenger_sex= np.unique(titanics[1:,1])
passenger_sex
passanger_sex_value = [sum(titanics[:,1] == passenger_sex[0]),
                       sum(titanics[:,1] == passenger_sex[1])]
passanger_sex_value
plt.subplot(1,2,1)
plt.bar(passenger_sex, passanger_sex_value)

passenger_survive= np.unique(titanics[1:,4])
passenger_survive

passenger_survive_value = [sum(titanics[:,4] == passenger_survive[0]),
                       sum(titanics[:,4] == passenger_survive[1])]

plt.subplot(1,2,2)
plt.bar(passenger_survive,passenger_survive_value)
plt.show()
